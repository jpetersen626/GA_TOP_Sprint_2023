# %% [markdown]
# # Cleaning and Chunking CDC Case Surveillance Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2020 Dataset

# %%
df_2020 = pd.read_csv('../data/cdc/CDC_2020.csv', index_col=0, 
            dtype={'res_county': 'string', 'underlying_conditions_yn': 'string'})

# %%
df_2020.head()
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 2    2020-11        MA             25.0      ESSEX           25009.0
# 4    2020-12        MO             29.0     PLATTE           29165.0
# 7    2020-08        TX             48.0   MAVERICK           48323.0
# 8    2020-09        MN             27.0     BECKER           27005.0
# 9    2020-11        KY             21.0    LINCOLN           21137.0
#
#         age_group     sex     race            ethnicity  \
# 2  18 to 49 years  Female      NaN                  NaN
# 4  18 to 49 years  Female  Unknown              Unknown
# 7  18 to 49 years    Male    White      Hispanic/Latino
# 8  50 to 64 years  Female    White  Non-Hispanic/Latino
# 9  18 to 49 years    Male    White  Non-Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval              process  \
# 2                              0.0                  NaN              Missing
# 4                              0.0                  NaN              Missing
# 7                              NaN                 -1.0              Missing
# 8                              0.0                  0.0              Missing
# 9                              0.0                  NaN  Clinical evaluation
#
#   exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 2     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 4     Missing  Laboratory-confirmed case        Missing  Unknown  Missing
# 7     Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 8         Yes  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 9         Yes  Laboratory-confirmed case        Unknown       No  Missing
#
#   death_yn underlying_conditions_yn
# 2  Missing                     <NA>
# 4  Unknown                     <NA>
# 7       No                     <NA>
# 8       No                     <NA>
# 9       No                      Yes

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20109295 entries, 2 to 456923
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_month                       object
#  1   res_state                        object
#  2   state_fips_code                  float64
#  3   res_county                       string
#  4   county_fips_code                 float64
#  5   age_group                        object
#  6   sex                              object
#  7   race                             object
#  8   ethnicity                        object
#  9   case_positive_specimen_interval  float64
#  10  case_onset_interval              float64
#  11  process                          object
#  12  exposure_yn                      object
#  13  current_status                   object
#  14  symptom_status                   object
#  15  hosp_yn                          object
#  16  icu_yn                           object
#  17  death_yn                         object
#  18  underlying_conditions_yn         string
# dtypes: float64(4), object(13), string(2)
# memory usage: 3.0+ GB

# %%
df_2020.sort_values(by='case_month', ascending=False, inplace=True)

# %%
df_2020[df_2020['state_fips_code'].isnull()]
# Out:
#       case_month res_state  state_fips_code res_county  county_fips_code  \
# 45405    2020-12       NaN              NaN       <NA>               NaN
# 45409    2020-12       NaN              NaN       <NA>               NaN
# 45413    2020-12       NaN              NaN       <NA>               NaN
# 45417    2020-12       NaN              NaN       <NA>               NaN
# 45389    2020-12       NaN              NaN       <NA>               NaN
# ...          ...       ...              ...        ...               ...
# 50726    2020-01       NaN              NaN       <NA>               NaN
# 50710    2020-01       NaN              NaN       <NA>               NaN
# 50714    2020-01       NaN              NaN       <NA>               NaN
# 50718    2020-01       NaN              NaN       <NA>               NaN
# 50722    2020-01       NaN              NaN       <NA>               NaN
#
#       age_group  sex race ethnicity  case_positive_specimen_interval  \
# 45405       NaN  NaN  NaN       NaN                              0.0
# 45409       NaN  NaN  NaN       NaN                              NaN
# 45413       NaN  NaN  NaN       NaN                              0.0
# 45417       NaN  NaN  NaN       NaN                              NaN
# 45389       NaN  NaN  NaN       NaN                              NaN
# ...         ...  ...  ...       ...                              ...
# 50726       NaN  NaN  NaN       NaN                             50.0
# 50710       NaN  NaN  NaN       NaN                             11.0
# 50714       NaN  NaN  NaN       NaN                             50.0
# 50718       NaN  NaN  NaN       NaN                             47.0
# 50722       NaN  NaN  NaN       NaN                              NaN
#
#        case_onset_interval              process exposure_yn  \
# 45405                  NaN              Missing     Missing
# 45409                  NaN              Missing     Missing
# 45413                  NaN              Missing     Missing
# 45417                  NaN              Missing     Missing
# 45389                  NaN              Missing     Missing
# ...                    ...                  ...         ...
# 50726                  NaN             Multiple         Yes
# 50710                  NaN              Missing         Yes
# 50714                  NaN  Laboratory reported         Yes
# 50718                  NaN              Missing     Missing
# 50722                  NaN              Missing     Missing
#
#                   current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 45405  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 45409  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 45413  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 45417  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 45389  Laboratory-confirmed case        Missing       No  Missing      NaN
# ...                          ...            ...      ...      ...      ...
# 50726  Laboratory-confirmed case    Symptomatic       No       No       No
# 50710  Laboratory-confirmed case    Symptomatic      Yes  Missing       No
# 50714  Laboratory-confirmed case    Symptomatic       No  Missing       No
# 50718  Laboratory-confirmed case    Symptomatic       No       No       No
# 50722  Laboratory-confirmed case    Symptomatic       No  Missing       No
#
#       underlying_conditions_yn
# 45405                     <NA>
# 45409                     <NA>
# 45413                     <NA>
# 45417                     <NA>
# 45389                     <NA>
# ...                        ...
# 50726                     <NA>
# 50710                      Yes
# 50714                     <NA>
# 50718                     <NA>
# 50722                     <NA>
#
# [457 rows x 19 columns]

# %% [markdown]
# #### Dropping the rows with no location information

# %%
df_2020 = df_2020[df_2020['state_fips_code'].notnull()]

# %%
df_2020
# Out:
#        case_month res_state  state_fips_code res_county  county_fips_code  \
# 106080    2020-12        CA              6.0     ORANGE            6059.0
# 299113    2020-12        AZ              4.0    COCHISE            4003.0
# 299333    2020-12        MI             26.0    LENAWEE           26091.0
# 329729    2020-12        TX             48.0    CAMERON           48061.0
# 299319    2020-12        OH             39.0  ASHTABULA           39007.0
# ...           ...       ...              ...        ...               ...
# 173108    2020-01        MI             26.0       <NA>               NaN
# 3609      2020-01        FL             12.0     ORANGE           12095.0
# 214904    2020-01        NY             36.0       <NA>               NaN
# 88464     2020-01        TN             47.0   DAVIDSON           47037.0
# 448182    2020-01        NY             36.0     ONEIDA           36065.0
#
#              age_group     sex            race            ethnicity  \
# 106080  18 to 49 years    Male           White      Hispanic/Latino
# 299113  18 to 49 years  Female  Multiple/Other  Non-Hispanic/Latino
# 299333  18 to 49 years  Female           White  Non-Hispanic/Latino
# 329729    0 - 17 years    Male         Missing              Unknown
# 299319  50 to 64 years    Male         Unknown              Unknown
# ...                ...     ...             ...                  ...
# 173108             NaN     NaN             NaN                  NaN
# 3609               NaN     NaN             NaN                  NaN
# 214904             NaN     NaN             NaN                  NaN
# 88464              NaN     NaN             NaN                  NaN
# 448182  18 to 49 years  Female           White              Unknown
#
#         case_positive_specimen_interval  case_onset_interval  process  \
# 106080                              NaN                  NaN  Missing
# 299113                              NaN                  0.0  Missing
# 299333                              NaN                  NaN  Missing
# 329729                              NaN                  NaN  Missing
# 299319                              0.0                  0.0  Missing
# ...                                 ...                  ...      ...
# 173108                              NaN                  0.0  Missing
# 3609                              105.0                  0.0  Missing
# 214904                              NaN                  0.0  Missing
# 88464                              48.0                  0.0  Missing
# 448182                              0.0                  NaN  Missing
#
#        exposure_yn             current_status symptom_status  hosp_yn  \
# 106080     Missing  Laboratory-confirmed case        Unknown  Missing
# 299113     Missing  Laboratory-confirmed case    Symptomatic       No
# 299333     Missing  Laboratory-confirmed case        Missing       No
# 329729     Missing  Laboratory-confirmed case        Missing  Missing
# 299319     Missing  Laboratory-confirmed case    Symptomatic  Missing
# ...            ...                        ...            ...      ...
# 173108     Missing  Laboratory-confirmed case    Symptomatic       No
# 3609       Missing  Laboratory-confirmed case    Symptomatic       No
# 214904     Missing  Laboratory-confirmed case    Symptomatic       No
# 88464      Missing  Laboratory-confirmed case    Symptomatic  Missing
# 448182     Missing  Laboratory-confirmed case        Missing  Missing
#
#          icu_yn death_yn underlying_conditions_yn
# 106080  Missing  Missing                     <NA>
# 299113  Missing       No                     <NA>
# 299333  Missing       No                      Yes
# 329729  Missing  Missing                     <NA>
# 299319  Missing  Unknown                     <NA>
# ...         ...      ...                      ...
# 173108  Missing       No                     <NA>
# 3609    Missing  Missing                     <NA>
# 214904  Missing       No                     <NA>
# 88464   Missing  Missing                     <NA>
# 448182  Missing       No                     <NA>
#
# [20108838 rows x 19 columns]

# %%
df_2020['state_fips_code'] = df_2020['state_fips_code'].astype('int')
df_2020['state_fips_code']
# Out:
# 106080     6
# 299113     4
# 299333    26
# 329729    48
# 299319    39
#           ..
# 173108    26
# 3609      12
# 214904    36
# 88464     47
# 448182    36
# Name: state_fips_code, Length: 20108838, dtype: int32

# %%
df_2020['county_fips_code'] = df_2020['county_fips_code'].replace(np.NaN, 0).astype('int')
df_2020['county_fips_code']
# Out:
# 106080     6059
# 299113     4003
# 299333    26091
# 329729    48061
# 299319    39007
#           ...
# 173108        0
# 3609      12095
# 214904        0
# 88464     47037
# 448182    36065
# Name: county_fips_code, Length: 20108838, dtype: int32

# %% [markdown]
# > Changing the NaN values to 0 in order to change the dtype for this column to 'int'

# %% [markdown]
# #### Splitting the dataset into 6 month periods

# %%
df_2020_2 = df_2020[df_2020['case_month'] >= '2020-07']
df_2020_1 = df_2020[df_2020['case_month'] <= '2020-06']

# %%
df_2020_1.reset_index(drop=True, inplace=True)
df_2020_2.reset_index(drop=True, inplace=True)

# %%
df_2020_1
# Out:
#         case_month res_state  state_fips_code res_county  county_fips_code  \
# 0          2020-06        MO               29     JASPER             29097
# 1          2020-06        NC               37     GASTON             37071
# 2          2020-06        SC               45     DILLON             45033
# 3          2020-06        WI               55      BROWN             55009
# 4          2020-06        NJ               34   SOMERSET             34035
# ...            ...       ...              ...        ...               ...
# 3008091    2020-01        MI               26       <NA>                 0
# 3008092    2020-01        FL               12     ORANGE             12095
# 3008093    2020-01        NY               36       <NA>                 0
# 3008094    2020-01        TN               47   DAVIDSON             47037
# 3008095    2020-01        NY               36     ONEIDA             36065
#
#               age_group     sex            race            ethnicity  \
# 0        18 to 49 years  Female           White  Non-Hispanic/Latino
# 1        18 to 49 years    Male           White  Non-Hispanic/Latino
# 2        18 to 49 years    Male           Black  Non-Hispanic/Latino
# 3        18 to 49 years  Female  Multiple/Other  Non-Hispanic/Latino
# 4        18 to 49 years    Male         Unknown              Missing
# ...                 ...     ...             ...                  ...
# 3008091             NaN     NaN             NaN                  NaN
# 3008092             NaN     NaN             NaN                  NaN
# 3008093             NaN     NaN             NaN                  NaN
# 3008094             NaN     NaN             NaN                  NaN
# 3008095  18 to 49 years  Female           White              Unknown
#
#          case_positive_specimen_interval  case_onset_interval  process  \
# 0                                    0.0                  NaN  Missing
# 1                                    0.0                  0.0  Missing
# 2                                    NaN                  0.0  Missing
# 3                                    NaN                  0.0  Missing
# 4                                    NaN                  NaN  Missing
# ...                                  ...                  ...      ...
# 3008091                              NaN                  0.0  Missing
# 3008092                            105.0                  0.0  Missing
# 3008093                              NaN                  0.0  Missing
# 3008094                             48.0                  0.0  Missing
# 3008095                              0.0                  NaN  Missing
#
#         exposure_yn             current_status symptom_status  hosp_yn  \
# 0           Missing  Laboratory-confirmed case        Missing  Unknown
# 1           Unknown  Laboratory-confirmed case    Symptomatic       No
# 2           Missing  Laboratory-confirmed case    Symptomatic       No
# 3           Missing  Laboratory-confirmed case    Symptomatic       No
# 4           Missing  Laboratory-confirmed case        Missing  Missing
# ...             ...                        ...            ...      ...
# 3008091     Missing  Laboratory-confirmed case    Symptomatic       No
# 3008092     Missing  Laboratory-confirmed case    Symptomatic       No
# 3008093     Missing  Laboratory-confirmed case    Symptomatic       No
# 3008094     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 3008095     Missing  Laboratory-confirmed case        Missing  Missing
#
#           icu_yn death_yn underlying_conditions_yn
# 0        Missing  Unknown                     <NA>
# 1        Unknown       No                     <NA>
# 2        Missing       No                     <NA>
# 3        Missing      NaN                     <NA>
# 4        Missing       No                     <NA>
# ...          ...      ...                      ...
# 3008091  Missing       No                     <NA>
# 3008092  Missing  Missing                     <NA>
# 3008093  Missing       No                     <NA>
# 3008094  Missing  Missing                     <NA>
# 3008095  Missing       No                     <NA>
#
# [3008096 rows x 19 columns]

# %%
df_2020_2
# Out:
#          case_month res_state  state_fips_code res_county  county_fips_code  \
# 0           2020-12        CA                6     ORANGE              6059
# 1           2020-12        AZ                4    COCHISE              4003
# 2           2020-12        MI               26    LENAWEE             26091
# 3           2020-12        TX               48    CAMERON             48061
# 4           2020-12        OH               39  ASHTABULA             39007
# ...             ...       ...              ...        ...               ...
# 17100737    2020-07        TX               48   MAVERICK             48323
# 17100738    2020-07        TX               48   VICTORIA             48469
# 17100739    2020-07        TX               48   MCLENNAN             48309
# 17100740    2020-07        NY               36     ALBANY             36001
# 17100741    2020-07        CA                6     ORANGE              6059
#
#                age_group     sex            race            ethnicity  \
# 0         18 to 49 years    Male           White      Hispanic/Latino
# 1         18 to 49 years  Female  Multiple/Other  Non-Hispanic/Latino
# 2         18 to 49 years  Female           White  Non-Hispanic/Latino
# 3           0 - 17 years    Male         Missing              Unknown
# 4         50 to 64 years    Male         Unknown              Unknown
# ...                  ...     ...             ...                  ...
# 17100737  18 to 49 years    Male           White      Hispanic/Latino
# 17100738  50 to 64 years  Female         Unknown              Unknown
# 17100739  18 to 49 years    Male         Unknown              Unknown
# 17100740  18 to 49 years    Male           White  Non-Hispanic/Latino
# 17100741  18 to 49 years  Female         Unknown              Unknown
#
#           case_positive_specimen_interval  case_onset_interval  process  \
# 0                                     NaN                  NaN  Missing
# 1                                     NaN                  0.0  Missing
# 2                                     NaN                  NaN  Missing
# 3                                     NaN                  NaN  Missing
# 4                                     0.0                  0.0  Missing
# ...                                   ...                  ...      ...
# 17100737                              NaN                 -3.0  Missing
# 17100738                              NaN                  NaN  Missing
# 17100739                              NaN                  NaN  Missing
# 17100740                              0.0                  NaN  Missing
# 17100741                              NaN                  NaN  Missing
#
#          exposure_yn             current_status symptom_status  hosp_yn  \
# 0            Missing  Laboratory-confirmed case        Unknown  Missing
# 1            Missing  Laboratory-confirmed case    Symptomatic       No
# 2            Missing  Laboratory-confirmed case        Missing       No
# 3            Missing  Laboratory-confirmed case        Missing  Missing
# 4            Missing  Laboratory-confirmed case    Symptomatic  Missing
# ...              ...                        ...            ...      ...
# 17100737     Missing  Laboratory-confirmed case    Symptomatic       No
# 17100738     Missing  Laboratory-confirmed case        Missing  Missing
# 17100739     Missing  Laboratory-confirmed case        Missing  Unknown
# 17100740     Missing  Laboratory-confirmed case        Missing       No
# 17100741     Missing  Laboratory-confirmed case        Unknown  Missing
#
#            icu_yn death_yn underlying_conditions_yn
# 0         Missing  Missing                     <NA>
# 1         Missing       No                     <NA>
# 2         Missing       No                      Yes
# 3         Missing  Missing                     <NA>
# 4         Missing  Unknown                     <NA>
# ...           ...      ...                      ...
# 17100737  Missing       No                     <NA>
# 17100738  Missing  Missing                     <NA>
# 17100739  Missing  Missing                     <NA>
# 17100740  Missing       No                     <NA>
# 17100741  Missing  Missing                     <NA>
#
# [17100742 rows x 19 columns]

# %% [markdown]
# #### Exporting cleaned 2020 datasets

# %%
df_2020.to_csv('../data/cdc/CDC_2020_cleaned.csv', index=False)
df_2020_1.to_csv('../data/cdc/CDC_2020_1_cleaned.csv', index=False)
df_2020_2.to_csv('../data/cdc/CDC_2020_2_cleaned.csv', index=False)
