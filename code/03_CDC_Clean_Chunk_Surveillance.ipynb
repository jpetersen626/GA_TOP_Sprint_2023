# %% [markdown]
# # Cleaning and Chunking CDC Case Surveillance Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2021 Dataset

# %%
df_2021 = pd.read_csv('../data/cdc/CDC_2021.csv', index_col=0, 
            dtype={'res_county': 'string', 'underlying_conditions_yn': 'string'})

# %%
df_2021.head()
# Out:
#    case_month res_state  state_fips_code res_county  county_fips_code  \
# 0     2021-08        WI             55.0     OCONTO           55083.0
# 3     2021-12        OH             39.0     LORAIN           39093.0
# 5     2021-01        VA             51.0       PAGE           51139.0
# 11    2021-08        IN             18.0    WHITLEY           18183.0
# 13    2021-11        ID             16.0     BONNER           16017.0
#
#          age_group     sex     race            ethnicity  \
# 0        65+ years    Male    White  Non-Hispanic/Latino
# 3   18 to 49 years  Female  Unknown              Unknown
# 5   18 to 49 years    Male      NaN                  NaN
# 11  18 to 49 years    Male    White  Non-Hispanic/Latino
# 13       65+ years    Male    White  Non-Hispanic/Latino
#
#     case_positive_specimen_interval  case_onset_interval  \
# 0                               NaN                  0.0
# 3                               NaN                  NaN
# 5                               0.0                  NaN
# 11                              0.0                  NaN
# 13                              0.0                  NaN
#
#                  process exposure_yn             current_status  \
# 0                Missing     Missing              Probable Case
# 3                Missing     Missing              Probable Case
# 5   Routine surveillance     Missing              Probable Case
# 11               Missing     Missing  Laboratory-confirmed case
# 13   Clinical evaluation     Missing  Laboratory-confirmed case
#
#    symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0     Symptomatic       No  Missing       No                     <NA>
# 3         Missing  Missing  Missing  Unknown                     <NA>
# 5         Missing  Missing  Missing      NaN                     <NA>
# 11        Missing       No  Missing       No                     <NA>
# 13        Missing  Missing  Missing      NaN                     <NA>

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34437682 entries, 0 to 456921
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_month                       object
#  1   res_state                        object
#  2   state_fips_code                  float64
#  3   res_county                       string
#  4   county_fips_code                 float64
#  5   age_group                        object
#  6   sex                              object
#  7   race                             object
#  8   ethnicity                        object
#  9   case_positive_specimen_interval  float64
#  10  case_onset_interval              float64
#  11  process                          object
#  12  exposure_yn                      object
#  13  current_status                   object
#  14  symptom_status                   object
#  15  hosp_yn                          object
#  16  icu_yn                           object
#  17  death_yn                         object
#  18  underlying_conditions_yn         string
# dtypes: float64(4), object(13), string(2)
# memory usage: 5.1+ GB

# %%
df_2021.sort_values(by='case_month', ascending=False, inplace=True)

# %%
df_2021[df_2021['state_fips_code'].isnull()]
# Out:
#       case_month res_state  state_fips_code res_county  county_fips_code  \
# 47641    2021-11       NaN              NaN       <NA>               NaN
# 47657    2021-11       NaN              NaN       <NA>               NaN
# 47645    2021-11       NaN              NaN       <NA>               NaN
# 47653    2021-11       NaN              NaN       <NA>               NaN
# 47649    2021-11       NaN              NaN       <NA>               NaN
# ...          ...       ...              ...        ...               ...
# 44982    2021-01       NaN              NaN       <NA>               NaN
# 44958    2021-01       NaN              NaN       <NA>               NaN
# 44962    2021-01       NaN              NaN       <NA>               NaN
# 44966    2021-01       NaN              NaN       <NA>               NaN
# 44970    2021-01       NaN              NaN       <NA>               NaN
#
#       age_group  sex race ethnicity  case_positive_specimen_interval  \
# 47641       NaN  NaN  NaN       NaN                              NaN
# 47657       NaN  NaN  NaN       NaN                              NaN
# 47645       NaN  NaN  NaN       NaN                              NaN
# 47653       NaN  NaN  NaN       NaN                              NaN
# 47649       NaN  NaN  NaN       NaN                              NaN
# ...         ...  ...  ...       ...                              ...
# 44982       NaN  NaN  NaN       NaN                              NaN
# 44958       NaN  NaN  NaN       NaN                              NaN
# 44962       NaN  NaN  NaN       NaN                              NaN
# 44966       NaN  NaN  NaN       NaN                              NaN
# 44970       NaN  NaN  NaN       NaN                              NaN
#
#        case_onset_interval  process exposure_yn             current_status  \
# 47641                  NaN  Missing     Missing  Laboratory-confirmed case
# 47657                  NaN  Missing     Missing              Probable Case
# 47645                  NaN  Missing     Missing  Laboratory-confirmed case
# 47653                  NaN  Missing     Missing              Probable Case
# 47649                  NaN  Missing     Missing              Probable Case
# ...                    ...      ...         ...                        ...
# 44982                  NaN  Missing         Yes  Laboratory-confirmed case
# 44958                  0.0  Missing         Yes  Laboratory-confirmed case
# 44962                  0.0  Missing         Yes  Laboratory-confirmed case
# 44966                  0.0  Missing         Yes  Laboratory-confirmed case
# 44970                  NaN  Missing         Yes  Laboratory-confirmed case
#
#       symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 47641        Missing  Missing  Missing  Missing                     <NA>
# 47657        Missing  Missing  Missing  Missing                     <NA>
# 47645        Missing  Missing  Missing  Missing                     <NA>
# 47653        Missing  Missing  Missing  Missing                     <NA>
# 47649        Missing  Missing  Missing  Missing                     <NA>
# ...              ...      ...      ...      ...                      ...
# 44982   Asymptomatic       No  Missing       No                     <NA>
# 44958    Symptomatic       No       No       No                     <NA>
# 44962    Symptomatic       No       No       No                     <NA>
# 44966    Symptomatic       No       No       No                     <NA>
# 44970    Symptomatic       No       No       No                     <NA>
#
# [517 rows x 19 columns]

# %% [markdown]
# #### Dropping the rows with no location information

# %%
df_2021 = df_2021[df_2021['state_fips_code'].notnull()]

# %%
df_2021
# Out:
#        case_month res_state  state_fips_code    res_county  county_fips_code  \
# 456921    2021-12        IN             18.0       CLINTON           18023.0
# 115503    2021-12        NY             36.0        NASSAU           36059.0
# 119111    2021-12        AZ              4.0      MARICOPA            4013.0
# 397465    2021-12        LA             22.0        ACADIA           22001.0
# 115537    2021-12        NJ             34.0         ESSEX           34013.0
# ...           ...       ...              ...           ...               ...
# 390832    2021-01        PA             42.0  PHILADELPHIA           42101.0
# 258196    2021-01        TX             48.0       LUBBOCK           48303.0
# 258207    2021-01        KY             21.0       DAVIESS           21059.0
# 390816    2021-01        TX             48.0        DALLAS           48113.0
# 300097    2021-01        CO              8.0        DENVER            8031.0
#
#              age_group     sex     race            ethnicity  \
# 456921  50 to 64 years    Male    White  Non-Hispanic/Latino
# 115503       65+ years    Male  Missing              Unknown
# 119111  50 to 64 years    Male    White  Non-Hispanic/Latino
# 397465  50 to 64 years  Female    White  Non-Hispanic/Latino
# 115537  18 to 49 years    Male    White  Non-Hispanic/Latino
# ...                ...     ...      ...                  ...
# 390832  18 to 49 years  Female      NaN                  NaN
# 258196  18 to 49 years    Male    White      Hispanic/Latino
# 258207  18 to 49 years  Female    White  Non-Hispanic/Latino
# 390816  50 to 64 years  Female    White  Non-Hispanic/Latino
# 300097  50 to 64 years  Female    White  Non-Hispanic/Latino
#
#         case_positive_specimen_interval  case_onset_interval  process  \
# 456921                              0.0                  NaN  Missing
# 115503                              NaN                  NaN  Missing
# 119111                              NaN                  0.0  Missing
# 397465                              0.0                  NaN  Missing
# 115537                              0.0                  NaN  Missing
# ...                                 ...                  ...      ...
# 390832                              0.0                  NaN  Missing
# 258196                              NaN                  NaN  Missing
# 258207                              NaN                  0.0  Missing
# 390816                              NaN                  NaN  Missing
# 300097                              NaN                  0.0  Missing
#
#        exposure_yn             current_status symptom_status  hosp_yn  \
# 456921     Missing              Probable Case        Missing       No
# 115503     Missing  Laboratory-confirmed case        Missing  Missing
# 119111     Missing  Laboratory-confirmed case    Symptomatic       No
# 397465     Missing  Laboratory-confirmed case        Unknown  Unknown
# 115537     Missing  Laboratory-confirmed case        Missing       No
# ...            ...                        ...            ...      ...
# 390832     Missing  Laboratory-confirmed case        Unknown  Unknown
# 258196     Missing  Laboratory-confirmed case        Missing  Missing
# 258207         Yes  Laboratory-confirmed case    Symptomatic       No
# 390816     Missing  Laboratory-confirmed case        Missing       No
# 300097     Missing  Laboratory-confirmed case    Symptomatic       No
#
#          icu_yn death_yn underlying_conditions_yn
# 456921  Missing       No                     <NA>
# 115503  Missing       No                     <NA>
# 119111  Missing       No                     <NA>
# 397465  Unknown  Missing                     <NA>
# 115537  Missing       No                     <NA>
# ...         ...      ...                      ...
# 390832  Unknown  Unknown                     <NA>
# 258196  Missing  Missing                     <NA>
# 258207  Missing       No                     <NA>
# 390816  Missing       No                     <NA>
# 300097  Missing  Missing                     <NA>
#
# [34437165 rows x 19 columns]

# %%
df_2021['state_fips_code'] = df_2021['state_fips_code'].astype('int')
df_2021['state_fips_code']
# Out:
# 456921    18
# 115503    36
# 119111     4
# 397465    22
# 115537    34
#           ..
# 390832    42
# 258196    48
# 258207    21
# 390816    48
# 300097     8
# Name: state_fips_code, Length: 34437165, dtype: int32

# %%
df_2021['county_fips_code'] = df_2021['county_fips_code'].replace(np.NaN, 0).astype('int')
df_2021['county_fips_code']
# Out:
# 456921    18023
# 115503    36059
# 119111     4013
# 397465    22001
# 115537    34013
#           ...
# 390832    42101
# 258196    48303
# 258207    21059
# 390816    48113
# 300097     8031
# Name: county_fips_code, Length: 34437165, dtype: int32

# %% [markdown]
# > Changing the NaN values to 0 in order to change the dtype for this column to 'int'

# %% [markdown]
# #### Splitting the dataset into 6 month periods

# %%
df_2021_2 = df_2021[df_2021['case_month'] >= '2021-07']
df_2021_1 = df_2021[df_2021['case_month'] <= '2021-06']

# %%
df_2021_1.reset_index(drop=True, inplace=True)
df_2021_2.reset_index(drop=True, inplace=True)

# %%
df_2021_1
# Out:
#          case_month res_state  state_fips_code    res_county  \
# 0           2021-06        MA               25       NORFOLK
# 1           2021-06        MI               26       OAKLAND
# 2           2021-06        MI               26       GENESEE
# 3           2021-06        FL               12    MIAMI-DADE
# 4           2021-06        RI               44    WASHINGTON
# ...             ...       ...              ...           ...
# 12747354    2021-01        PA               42  PHILADELPHIA
# 12747355    2021-01        TX               48       LUBBOCK
# 12747356    2021-01        KY               21       DAVIESS
# 12747357    2021-01        TX               48        DALLAS
# 12747358    2021-01        CO                8        DENVER
#
#           county_fips_code       age_group     sex     race  \
# 0                    25021  18 to 49 years    Male      NaN
# 1                    26125  50 to 64 years    Male  Unknown
# 2                    26049  18 to 49 years  Female    Black
# 3                    12086       65+ years  Female    White
# 4                    44009    0 - 17 years    Male    White
# ...                    ...             ...     ...      ...
# 12747354             42101  18 to 49 years  Female      NaN
# 12747355             48303  18 to 49 years    Male    White
# 12747356             21059  18 to 49 years  Female    White
# 12747357             48113  50 to 64 years  Female    White
# 12747358              8031  50 to 64 years  Female    White
#
#                     ethnicity  case_positive_specimen_interval  \
# 0                         NaN                              0.0
# 1                     Unknown                              NaN
# 2                     Unknown                              NaN
# 3             Hispanic/Latino                              0.0
# 4         Non-Hispanic/Latino                              NaN
# ...                       ...                              ...
# 12747354                  NaN                              0.0
# 12747355      Hispanic/Latino                              NaN
# 12747356  Non-Hispanic/Latino                              NaN
# 12747357  Non-Hispanic/Latino                              NaN
# 12747358  Non-Hispanic/Latino                              NaN
#
#           case_onset_interval  process exposure_yn             current_status  \
# 0                         NaN  Missing     Missing  Laboratory-confirmed case
# 1                         NaN  Missing     Missing  Laboratory-confirmed case
# 2                         NaN  Missing     Missing  Laboratory-confirmed case
# 3                         0.0  Missing     Missing  Laboratory-confirmed case
# 4                         NaN  Missing     Missing  Laboratory-confirmed case
# ...                       ...      ...         ...                        ...
# 12747354                  NaN  Missing     Missing  Laboratory-confirmed case
# 12747355                  NaN  Missing     Missing  Laboratory-confirmed case
# 12747356                  0.0  Missing         Yes  Laboratory-confirmed case
# 12747357                  NaN  Missing     Missing  Laboratory-confirmed case
# 12747358                  0.0  Missing     Missing  Laboratory-confirmed case
#
#          symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0               Missing  Missing  Missing  Missing                     <NA>
# 1               Missing  Missing  Missing  Unknown                     <NA>
# 2               Missing  Missing  Missing  Unknown                     <NA>
# 3           Symptomatic       No  Missing       No                     <NA>
# 4               Missing  Missing  Missing       No                     <NA>
# ...                 ...      ...      ...      ...                      ...
# 12747354        Unknown  Unknown  Unknown  Unknown                     <NA>
# 12747355        Missing  Missing  Missing  Missing                     <NA>
# 12747356    Symptomatic       No  Missing       No                     <NA>
# 12747357        Missing       No  Missing       No                     <NA>
# 12747358    Symptomatic       No  Missing  Missing                     <NA>
#
# [12747359 rows x 19 columns]

# %%
df_2021_2
# Out:
#          case_month res_state  state_fips_code   res_county  county_fips_code  \
# 0           2021-12        IN               18      CLINTON             18023
# 1           2021-12        NY               36       NASSAU             36059
# 2           2021-12        AZ                4     MARICOPA              4013
# 3           2021-12        LA               22       ACADIA             22001
# 4           2021-12        NJ               34        ESSEX             34013
# ...             ...       ...              ...          ...               ...
# 21689801    2021-07        CA                6  LOS ANGELES              6037
# 21689802    2021-07        TX               48      TARRANT             48439
# 21689803    2021-07        OH               39     CUYAHOGA             39035
# 21689804    2021-07        TX               48       DENTON             48121
# 21689805    2021-07        TX               48       DALLAS             48113
#
#                age_group      sex     race            ethnicity  \
# 0         50 to 64 years     Male    White  Non-Hispanic/Latino
# 1              65+ years     Male  Missing              Unknown
# 2         50 to 64 years     Male    White  Non-Hispanic/Latino
# 3         50 to 64 years   Female    White  Non-Hispanic/Latino
# 4         18 to 49 years     Male    White  Non-Hispanic/Latino
# ...                  ...      ...      ...                  ...
# 21689801  18 to 49 years     Male    White  Non-Hispanic/Latino
# 21689802  18 to 49 years   Female  Unknown              Unknown
# 21689803  18 to 49 years     Male    White  Non-Hispanic/Latino
# 21689804       65+ years  Missing  Missing              Missing
# 21689805    0 - 17 years   Female  Unknown              Unknown
#
#           case_positive_specimen_interval  case_onset_interval  \
# 0                                     0.0                  NaN
# 1                                     NaN                  NaN
# 2                                     NaN                  0.0
# 3                                     0.0                  NaN
# 4                                     0.0                  NaN
# ...                                   ...                  ...
# 21689801                              NaN                  0.0
# 21689802                              NaN                  NaN
# 21689803                              1.0                  0.0
# 21689804                              NaN                  NaN
# 21689805                              NaN                  NaN
#
#                       process exposure_yn             current_status  \
# 0                     Missing     Missing              Probable Case
# 1                     Missing     Missing  Laboratory-confirmed case
# 2                     Missing     Missing  Laboratory-confirmed case
# 3                     Missing     Missing  Laboratory-confirmed case
# 4                     Missing     Missing  Laboratory-confirmed case
# ...                       ...         ...                        ...
# 21689801              Missing     Missing              Probable Case
# 21689802              Missing     Missing  Laboratory-confirmed case
# 21689803  Clinical evaluation         Yes  Laboratory-confirmed case
# 21689804              Missing     Missing  Laboratory-confirmed case
# 21689805              Missing     Missing  Laboratory-confirmed case
#
#          symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0               Missing       No  Missing       No                     <NA>
# 1               Missing  Missing  Missing       No                     <NA>
# 2           Symptomatic       No  Missing       No                     <NA>
# 3               Unknown  Unknown  Unknown  Missing                     <NA>
# 4               Missing       No  Missing       No                     <NA>
# ...                 ...      ...      ...      ...                      ...
# 21689801    Symptomatic       No  Missing  Missing                     <NA>
# 21689802        Missing  Missing  Missing  Missing                     <NA>
# 21689803    Symptomatic       No  Missing  Unknown                     <NA>
# 21689804        Missing  Missing  Missing  Missing                     <NA>
# 21689805        Missing       No  Missing       No                     <NA>
#
# [21689806 rows x 19 columns]

# %% [markdown]
# #### Exporting cleaned 2021 datasets

# %%
df_2021.to_csv('../data/cdc/CDC_2021_cleaned.csv', index=False)
df_2021_1.to_csv('../data/cdc/CDC_2021_1_cleaned.csv', index=False)
df_2021_2.to_csv('../data/cdc/CDC_2021_2_cleaned.csv', index=False)
